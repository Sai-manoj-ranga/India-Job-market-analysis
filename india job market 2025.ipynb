# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **READ** **DATASET**

# %%
ijm= pd.read_csv('ijmdataset.csv')
ijm
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 0          JOB1     Software Engineer       Amazon    Ahmedabad   Full-time
# 1          JOB2   Marketing Executive      Infosys    Ahmedabad  Internship
# 2          JOB3     Financial Analyst     Deloitte       Jaipur    Contract
# 3          JOB4      Business Analyst       Amazon        Delhi   Full-time
# 4          JOB5     Software Engineer      Infosys        Delhi   Full-time
# ...         ...                   ...          ...          ...         ...
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
#       Salary Range Experience Required Posted Date Application Deadline  \
# 0          5-8 LPA           2-5 years  16-01-2025           25-01-2025
# 1          5-8 LPA           2-5 years  25-12-2024           19-01-2025
# 2          20+ LPA          5-10 years  22-01-2025           29-01-2025
# 3          20+ LPA           2-5 years  07-01-2025           06-02-2025
# 4        12-20 LPA           10+ years  26-12-2024           08-01-2025
# ...            ...                 ...         ...                  ...
# 19995      5-8 LPA           2-5 years  13-01-2025           05-02-2025
# 19996      20+ LPA           0-2 years  08-01-2025           27-01-2025
# 19997      5-8 LPA          5-10 years  26-12-2024           16-01-2025
# 19998    12-20 LPA           2-5 years  20-01-2025           09-02-2025
# 19999      5-8 LPA           0-2 years  30-12-2024           13-01-2025
#
#        Job Portal  Number of Applicants Education Requirement  \
# 0        LinkedIn                    23                   PhD
# 1          Indeed                   462                   MBA
# 2      Naukri.com                   430                M.Tech
# 3        LinkedIn                   387                B.Tech
# 4          Indeed                   199                   MBA
# ...           ...                   ...                   ...
# 19995      Indeed                   171                   PhD
# 19996    LinkedIn                   482                   MBA
# 19997  Naukri.com                   319                   PhD
# 19998  Naukri.com                   178                M.Tech
# 19999      Indeed                    88                  B.Sc
#
#                                   Skills Required Remote/Onsite  \
# 0                                C++, SQL, Python        Remote
# 1                                SQL, C++, Python        Remote
# 2                  Machine Learning, Excel, React        Remote
# 3                   Machine Learning, Python, SQL        Hybrid
# 4                                UI/UX, C++, Java        Onsite
# ...                                           ...           ...
# 19995               Machine Learning, Python, AWS        Remote
# 19996  Digital Marketing, React, Machine Learning        Onsite
# 19997  Machine Learning, Excel, Digital Marketing        Onsite
# 19998                           Excel, C++, React        Onsite
# 19999                           Java, C++, Python        Remote
#
#           Company Size
# 0         Small (1-50)
# 1         Large (500+)
# 2         Large (500+)
# 3         Small (1-50)
# 4         Small (1-50)
# ...                ...
# 19995     Small (1-50)
# 19996  Medium (51-500)
# 19997     Small (1-50)
# 19998     Large (500+)
# 19999  Medium (51-500)
#
# [20000 rows x 15 columns]

# %% [markdown]
# **BASIC FUNCTIONS**

# %%
ijm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job ID                 20000 non-null  object
#  1   Job Title              20000 non-null  object
#  2   Company Name           20000 non-null  object
#  3   Job Location           20000 non-null  object
#  4   Job Type               20000 non-null  object
#  5   Salary Range           20000 non-null  object
#  6   Experience Required    20000 non-null  object
#  7   Posted Date            20000 non-null  object
#  8   Application Deadline   20000 non-null  object
#  9   Job Portal             20000 non-null  object
#  10  Number of Applicants   20000 non-null  int64
#  11  Education Requirement  20000 non-null  object
#  12  Skills Required        20000 non-null  object
#  13  Remote/Onsite          20000 non-null  object
#  14  Company Size           20000 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 2.3+ MB

# %%
ijm.columns
# Out:
# Index(['Job ID', 'Job Title', 'Company Name', 'Job Location', 'Job Type',
#        'Salary Range', 'Experience Required', 'Posted Date',
#        'Application Deadline', 'Job Portal', 'Number of Applicants',
#        'Education Requirement', 'Skills Required', 'Remote/Onsite',
#        'Company Size'],
#       dtype='object')

# %%
ijm.shape
# Out:
# (20000, 15)

# %%
ijm.head()
# Out:
#   Job ID            Job Title Company Name Job Location    Job Type  \
# 0   JOB1    Software Engineer       Amazon    Ahmedabad   Full-time
# 1   JOB2  Marketing Executive      Infosys    Ahmedabad  Internship
# 2   JOB3    Financial Analyst     Deloitte       Jaipur    Contract
# 3   JOB4     Business Analyst       Amazon        Delhi   Full-time
# 4   JOB5    Software Engineer      Infosys        Delhi   Full-time
#
#   Salary Range Experience Required Posted Date Application Deadline  \
# 0      5-8 LPA           2-5 years  16-01-2025           25-01-2025
# 1      5-8 LPA           2-5 years  25-12-2024           19-01-2025
# 2      20+ LPA          5-10 years  22-01-2025           29-01-2025
# 3      20+ LPA           2-5 years  07-01-2025           06-02-2025
# 4    12-20 LPA           10+ years  26-12-2024           08-01-2025
#
#    Job Portal  Number of Applicants Education Requirement  \
# 0    LinkedIn                    23                   PhD
# 1      Indeed                   462                   MBA
# 2  Naukri.com                   430                M.Tech
# 3    LinkedIn                   387                B.Tech
# 4      Indeed                   199                   MBA
#
#                   Skills Required Remote/Onsite  Company Size
# 0                C++, SQL, Python        Remote  Small (1-50)
# 1                SQL, C++, Python        Remote  Large (500+)
# 2  Machine Learning, Excel, React        Remote  Large (500+)
# 3   Machine Learning, Python, SQL        Hybrid  Small (1-50)
# 4                UI/UX, C++, Java        Onsite  Small (1-50)

# %%
ijm.tail()
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
#
#       Salary Range Experience Required Posted Date Application Deadline  \
# 19995      5-8 LPA           2-5 years  13-01-2025           05-02-2025
# 19996      20+ LPA           0-2 years  08-01-2025           27-01-2025
# 19997      5-8 LPA          5-10 years  26-12-2024           16-01-2025
# 19998    12-20 LPA           2-5 years  20-01-2025           09-02-2025
# 19999      5-8 LPA           0-2 years  30-12-2024           13-01-2025
#
#        Job Portal  Number of Applicants Education Requirement  \
# 19995      Indeed                   171                   PhD
# 19996    LinkedIn                   482                   MBA
# 19997  Naukri.com                   319                   PhD
# 19998  Naukri.com                   178                M.Tech
# 19999      Indeed                    88                  B.Sc
#
#                                   Skills Required Remote/Onsite  \
# 19995               Machine Learning, Python, AWS        Remote
# 19996  Digital Marketing, React, Machine Learning        Onsite
# 19997  Machine Learning, Excel, Digital Marketing        Onsite
# 19998                           Excel, C++, React        Onsite
# 19999                           Java, C++, Python        Remote
#
#           Company Size
# 19995     Small (1-50)
# 19996  Medium (51-500)
# 19997     Small (1-50)
# 19998     Large (500+)
# 19999  Medium (51-500)

# %%
ijm.nunique()
# Out:
# Job ID                   20000
# Job Title                   10
# Company Name                10
# Job Location                10
# Job Type                     4
# Salary Range                 5
# Experience Required          4
# Posted Date                 31
# Application Deadline        54
# Job Portal                   3
# Number of Applicants       491
# Education Requirement        5
# Skills Required            720
# Remote/Onsite                3
# Company Size                 3
# dtype: int64

# %%
ijm.isnull().sum()
# Out:
# Job ID                   0
# Job Title                0
# Company Name             0
# Job Location             0
# Job Type                 0
# Salary Range             0
# Experience Required      0
# Posted Date              0
# Application Deadline     0
# Job Portal               0
# Number of Applicants     0
# Education Requirement    0
# Skills Required          0
# Remote/Onsite            0
# Company Size             0
# dtype: int64

# %%
ijm.duplicated().sum()
# Out:
# 0

# %%
ijm['Company Name'].value_counts()
# Out:
# Company Name
# Amazon       2086
# Wipro        2069
# HCL          2023
# Google       2004
# Deloitte     1983
# Infosys      1981
# TCS          1979
# Microsoft    1977
# Accenture    1954
# IBM          1944
# Name: count, dtype: int64

# %%
ijm['Job Type'].unique()
# Out:
# array(['Full-time', 'Internship', 'Contract', 'Part-time'], dtype=object)

# %%
ijm['Job Title'].value_counts()
# Out:
# Job Title
# Cyber Security Analyst    2085
# Marketing Executive       2036
# Graphic Designer          2013
# Financial Analyst         2008
# Product Manager           2006
# Business Analyst          1989
# Data Scientist            1976
# HR Manager                1974
# Software Engineer         1971
# Sales Representative      1942
# Name: count, dtype: int64

# %%
ijm['Salary Range'].unique()
# Out:
# array(['5-8 LPA', '20+ LPA', '12-20 LPA', '3-5 LPA', '8-12 LPA'],
#       dtype=object)

# %%
ijm.describe(include='object')
# Out:
#        Job ID               Job Title Company Name Job Location   Job Type  \
# count   20000                   20000        20000        20000      20000
# unique  20000                      10           10           10          4
# top      JOB1  Cyber Security Analyst       Amazon    Hyderabad  Part-time
# freq        1                    2085         2086         2055       5111
#
#        Salary Range Experience Required Posted Date Application Deadline  \
# count         20000               20000       20000                20000
# unique            5                   4          31                   54
# top       12-20 LPA           10+ years  15-01-2025           23-01-2025
# freq           4066                5069         687                  667
#
#         Job Portal Education Requirement   Skills Required Remote/Onsite  \
# count        20000                 20000             20000         20000
# unique           3                     5               720             3
# top     Naukri.com                  B.Sc  React, SQL, Java        Remote
# freq          6791                  4023                43          6742
#
#         Company Size
# count          20000
# unique             3
# top     Small (1-50)
# freq            6718

# %%
ijm.sample(3)
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 7859    JOB7860            HR Manager       Google    Hyderabad   Full-time
# 18705  JOB18706  Sales Representative          TCS        Delhi   Part-time
# 17842  JOB17843      Business Analyst       Amazon       Jaipur  Internship
#
#       Salary Range Experience Required Posted Date Application Deadline  \
# 7859      8-12 LPA          5-10 years  11-01-2025           05-02-2025
# 18705      3-5 LPA           0-2 years  26-12-2024           16-01-2025
# 17842     8-12 LPA           2-5 years  02-01-2025           09-01-2025
#
#        Job Portal  Number of Applicants Education Requirement  \
# 7859   Naukri.com                   155                   MBA
# 18705    LinkedIn                    51                M.Tech
# 17842      Indeed                   493                B.Tech
#
#                         Skills Required Remote/Onsite     Company Size
# 7859                Excel, Java, Python        Hybrid     Large (500+)
# 18705     C++, UI/UX, Digital Marketing        Hybrid  Medium (51-500)
# 17842  Python, Digital Marketing, UI/UX        Hybrid     Small (1-50)

# %%
ijm.isnull()
# Out:
#        Job ID  Job Title  Company Name  Job Location  Job Type  Salary Range  \
# 0       False      False         False         False     False         False
# 1       False      False         False         False     False         False
# 2       False      False         False         False     False         False
# 3       False      False         False         False     False         False
# 4       False      False         False         False     False         False
# ...       ...        ...           ...           ...       ...           ...
# 19995   False      False         False         False     False         False
# 19996   False      False         False         False     False         False
# 19997   False      False         False         False     False         False
# 19998   False      False         False         False     False         False
# 19999   False      False         False         False     False         False
#
#        Experience Required  Posted Date  Application Deadline  Job Portal  \
# 0                    False        False                 False       False
# 1                    False        False                 False       False
# 2                    False        False                 False       False
# 3                    False        False                 False       False
# 4                    False        False                 False       False
# ...                    ...          ...                   ...         ...
# 19995                False        False                 False       False
# 19996                False        False                 False       False
# 19997                False        False                 False       False
# 19998                False        False                 False       False
# 19999                False        False                 False       False
#
#        Number of Applicants  Education Requirement  Skills Required  \
# 0                     False                  False            False
# 1                     False                  False            False
# 2                     False                  False            False
# 3                     False                  False            False
# 4                     False                  False            False
# ...                     ...                    ...              ...
# 19995                 False                  False            False
# 19996                 False                  False            False
# 19997                 False                  False            False
# 19998                 False                  False            False
# 19999                 False                  False            False
#
#        Remote/Onsite  Company Size
# 0              False         False
# 1              False         False
# 2              False         False
# 3              False         False
# 4              False         False
# ...              ...           ...
# 19995          False         False
# 19996          False         False
# 19997          False         False
# 19998          False         False
# 19999          False         False
#
# [20000 rows x 15 columns]

# %%
ijm.T
# Out:
#                                    0                    1      \
# Job ID                              JOB1                 JOB2
# Job Title              Software Engineer  Marketing Executive
# Company Name                      Amazon              Infosys
# Job Location                   Ahmedabad            Ahmedabad
# Job Type                       Full-time           Internship
# Salary Range                     5-8 LPA              5-8 LPA
# Experience Required            2-5 years            2-5 years
# Posted Date                   16-01-2025           25-12-2024
# Application Deadline          25-01-2025           19-01-2025
# Job Portal                      LinkedIn               Indeed
# Number of Applicants                  23                  462
# Education Requirement                PhD                  MBA
# Skills Required         C++, SQL, Python     SQL, C++, Python
# Remote/Onsite                     Remote               Remote
# Company Size                Small (1-50)         Large (500+)
#
#                                                 2      \
# Job ID                                           JOB3
# Job Title                           Financial Analyst
# Company Name                                 Deloitte
# Job Location                                   Jaipur
# Job Type                                     Contract
# Salary Range                                  20+ LPA
# Experience Required                        5-10 years
# Posted Date                                22-01-2025
# Application Deadline                       29-01-2025
# Job Portal                                 Naukri.com
# Number of Applicants                              430
# Education Requirement                          M.Tech
# Skills Required        Machine Learning, Excel, React
# Remote/Onsite                                  Remote
# Company Size                             Large (500+)
#
#                                                3                  4      \
# Job ID                                          JOB4               JOB5
# Job Title                           Business Analyst  Software Engineer
# Company Name                                  Amazon            Infosys
# Job Location                                   Delhi              Delhi
# Job Type                                   Full-time          Full-time
# Salary Range                                 20+ LPA          12-20 LPA
# Experience Required                        2-5 years          10+ years
# Posted Date                               07-01-2025         26-12-2024
# Application Deadline                      06-02-2025         08-01-2025
# Job Portal                                  LinkedIn             Indeed
# Number of Applicants                             387                199
# Education Requirement                         B.Tech                MBA
# Skills Required        Machine Learning, Python, SQL   UI/UX, C++, Java
# Remote/Onsite                                 Hybrid             Onsite
# Company Size                            Small (1-50)       Small (1-50)
#
#                                  5                  6      \
# Job ID                            JOB6               JOB7
# Job Title               Data Scientist  Software Engineer
# Company Name                     Wipro          Accenture
# Job Location                      Pune              Noida
# Job Type                    Internship          Full-time
# Salary Range                   5-8 LPA            5-8 LPA
# Experience Required         5-10 years         5-10 years
# Posted Date                 27-12-2024         30-12-2024
# Application Deadline        09-01-2025         13-01-2025
# Job Portal                      Indeed           LinkedIn
# Number of Applicants               281                489
# Education Requirement             B.Sc             B.Tech
# Skills Required        SQL, React, C++   SQL, Python, C++
# Remote/Onsite                   Remote             Hybrid
# Company Size              Large (500+)       Large (500+)
#
#                                                             7      \
# Job ID                                                       JOB8
# Job Title                                          Data Scientist
# Company Name                                                Wipro
# Job Location                                               Mumbai
# Job Type                                                 Contract
# Salary Range                                              5-8 LPA
# Experience Required                                     0-2 years
# Posted Date                                            10-01-2025
# Application Deadline                                   30-01-2025
# Job Portal                                             Naukri.com
# Number of Applicants                                          350
# Education Requirement                                      B.Tech
# Skills Required        React, Digital Marketing, Machine Learning
# Remote/Onsite                                              Onsite
# Company Size                                      Medium (51-500)
#
#                                      8                  9      ...  \
# Job ID                                JOB9              JOB10  ...
# Job Title              Marketing Executive  Financial Analyst  ...
# Company Name                           HCL          Microsoft  ...
# Job Location                     Ahmedabad               Pune  ...
# Job Type                         Part-time         Internship  ...
# Salary Range                       5-8 LPA          12-20 LPA  ...
# Experience Required             5-10 years         5-10 years  ...
# Posted Date                     21-01-2025         06-01-2025  ...
# Application Deadline            16-02-2025         22-01-2025  ...
# Job Portal                      Naukri.com             Indeed  ...
# Number of Applicants                   323                469  ...
# Education Requirement               B.Tech             B.Tech  ...
# Skills Required        Java, Python, Excel    SQL, React, C++  ...
# Remote/Onsite                       Onsite             Remote  ...
# Company Size               Medium (51-500)       Large (500+)  ...
#
#                                               19990  \
# Job ID                                     JOB19991
# Job Title                                HR Manager
# Company Name                                 Amazon
# Job Location                                  Noida
# Job Type                                  Full-time
# Salary Range                               8-12 LPA
# Experience Required                       2-5 years
# Posted Date                              18-01-2025
# Application Deadline                     29-01-2025
# Job Portal                               Naukri.com
# Number of Applicants                            112
# Education Requirement                        B.Tech
# Skills Required        Java, Digital Marketing, AWS
# Remote/Onsite                                Onsite
# Company Size                           Small (1-50)
#
#                                                19991  \
# Job ID                                      JOB19992
# Job Title                     Cyber Security Analyst
# Company Name                                     HCL
# Job Location                                  Jaipur
# Job Type                                  Internship
# Salary Range                                8-12 LPA
# Experience Required                       5-10 years
# Posted Date                               25-12-2024
# Application Deadline                      02-01-2025
# Job Portal                                    Indeed
# Number of Applicants                             460
# Education Requirement                         M.Tech
# Skills Required        SQL, Python, Machine Learning
# Remote/Onsite                                 Hybrid
# Company Size                         Medium (51-500)
#
#                                               19992              19993  \
# Job ID                                     JOB19993           JOB19994
# Job Title                         Financial Analyst         HR Manager
# Company Name                                    IBM            Infosys
# Job Location                                Kolkata              Noida
# Job Type                                 Internship          Full-time
# Salary Range                                5-8 LPA            3-5 LPA
# Experience Required                      5-10 years          2-5 years
# Posted Date                              29-12-2024         22-01-2025
# Application Deadline                     11-01-2025         12-02-2025
# Job Portal                               Naukri.com             Indeed
# Number of Applicants                            339                272
# Education Requirement                          B.Sc               B.Sc
# Skills Required        AWS, Java, Digital Marketing  React, Excel, C++
# Remote/Onsite                                Hybrid             Onsite
# Company Size                           Small (1-50)       Small (1-50)
#
#                                                19994  \
# Job ID                                      JOB19995
# Job Title                          Software Engineer
# Company Name                               Accenture
# Job Location                                   Noida
# Job Type                                  Internship
# Salary Range                                 3-5 LPA
# Experience Required                       5-10 years
# Posted Date                               01-01-2025
# Application Deadline                      13-01-2025
# Job Portal                                    Indeed
# Number of Applicants                             486
# Education Requirement                         B.Tech
# Skills Required        Digital Marketing, SQL, UI/UX
# Remote/Onsite                                 Remote
# Company Size                         Medium (51-500)
#
#                                                19995  \
# Job ID                                      JOB19996
# Job Title                        Marketing Executive
# Company Name                                Deloitte
# Job Location                                    Pune
# Job Type                                   Full-time
# Salary Range                                 5-8 LPA
# Experience Required                        2-5 years
# Posted Date                               13-01-2025
# Application Deadline                      05-02-2025
# Job Portal                                    Indeed
# Number of Applicants                             171
# Education Requirement                            PhD
# Skills Required        Machine Learning, Python, AWS
# Remote/Onsite                                 Remote
# Company Size                            Small (1-50)
#
#                                                             19996  \
# Job ID                                                   JOB19997
# Job Title                                        Business Analyst
# Company Name                                            Accenture
# Job Location                                            Bangalore
# Job Type                                               Internship
# Salary Range                                              20+ LPA
# Experience Required                                     0-2 years
# Posted Date                                            08-01-2025
# Application Deadline                                   27-01-2025
# Job Portal                                               LinkedIn
# Number of Applicants                                          482
# Education Requirement                                         MBA
# Skills Required        Digital Marketing, React, Machine Learning
# Remote/Onsite                                              Onsite
# Company Size                                      Medium (51-500)
#
#                                                             19997  \
# Job ID                                                   JOB19998
# Job Title                                        Graphic Designer
# Company Name                                                Wipro
# Job Location                                               Jaipur
# Job Type                                                Part-time
# Salary Range                                              5-8 LPA
# Experience Required                                    5-10 years
# Posted Date                                            26-12-2024
# Application Deadline                                   16-01-2025
# Job Portal                                             Naukri.com
# Number of Applicants                                          319
# Education Requirement                                         PhD
# Skills Required        Machine Learning, Excel, Digital Marketing
# Remote/Onsite                                              Onsite
# Company Size                                         Small (1-50)
#
#                                       19998              19999
# Job ID                             JOB19999           JOB20000
# Job Title              Sales Representative   Business Analyst
# Company Name                        Infosys          Accenture
# Job Location                        Kolkata             Mumbai
# Job Type                         Internship          Part-time
# Salary Range                      12-20 LPA            5-8 LPA
# Experience Required               2-5 years          0-2 years
# Posted Date                      20-01-2025         30-12-2024
# Application Deadline             09-02-2025         13-01-2025
# Job Portal                       Naukri.com             Indeed
# Number of Applicants                    178                 88
# Education Requirement                M.Tech               B.Sc
# Skills Required           Excel, C++, React  Java, C++, Python
# Remote/Onsite                        Onsite             Remote
# Company Size                   Large (500+)    Medium (51-500)
#
# [15 rows x 20000 columns]

# %% [markdown]
#  **DATA CLEANING**

# %%
ijm.drop_duplicates(inplace=True) 
uni_rows=ijm.shape[0] 
uni_rows #no of unique rows
# Out:
# 20000

# %%
ijm = ijm.dropna(subset=['Job Title']) #drops rows where the Job Title is missing

# %%
ijm['Salary Range'] = ijm['Salary Range'].str.replace(' LPA', '')
#Removes the ' LPA' text from salary values
ijm['Salary Range']
# Out:
# 0          5-8
# 1          5-8
# 2          20+
# 3          20+
# 4        12-20
#          ...
# 19995      5-8
# 19996      20+
# 19997      5-8
# 19998    12-20
# 19999      5-8
# Name: Salary Range, Length: 20000, dtype: object

# %% [markdown]
# **DATA FILTERING**

# %%
fulltime_h = ijm[(ijm['Job Type'] == 'Full-time') & (ijm['Number of Applicants'] > 100)]
fulltime_h.head()
# Out:
#    Job ID               Job Title Company Name Job Location   Job Type  \
# 3    JOB4        Business Analyst       Amazon        Delhi  Full-time
# 4    JOB5       Software Engineer      Infosys        Delhi  Full-time
# 6    JOB7       Software Engineer    Accenture        Noida  Full-time
# 25  JOB26  Cyber Security Analyst    Microsoft        Delhi  Full-time
# 27  JOB28          Data Scientist       Google       Jaipur  Full-time
#
#    Salary Range Experience Required Posted Date Application Deadline  \
# 3           20+           2-5 years  07-01-2025           06-02-2025
# 4         12-20           10+ years  26-12-2024           08-01-2025
# 6           5-8          5-10 years  30-12-2024           13-01-2025
# 25        12-20           0-2 years  09-01-2025           07-02-2025
# 27          5-8          5-10 years  15-01-2025           27-01-2025
#
#    Job Portal  Number of Applicants Education Requirement  \
# 3    LinkedIn                   387                B.Tech
# 4      Indeed                   199                   MBA
# 6    LinkedIn                   489                B.Tech
# 25   LinkedIn                   133                B.Tech
# 27     Indeed                   288                B.Tech
#
#                   Skills Required Remote/Onsite     Company Size
# 3   Machine Learning, Python, SQL        Hybrid     Small (1-50)
# 4                UI/UX, C++, Java        Onsite     Small (1-50)
# 6                SQL, Python, C++        Hybrid     Large (500+)
# 25               UI/UX, Java, C++        Remote  Medium (51-500)
# 27                 Java, AWS, C++        Onsite  Medium (51-500)

# %%
recent = ijm[ijm['Posted Date'] > '2025-01-01']
recent.head()
# Out:
#   Job ID            Job Title Company Name Job Location    Job Type  \
# 1   JOB2  Marketing Executive      Infosys    Ahmedabad  Internship
# 2   JOB3    Financial Analyst     Deloitte       Jaipur    Contract
# 4   JOB5    Software Engineer      Infosys        Delhi   Full-time
# 5   JOB6       Data Scientist        Wipro         Pune  Internship
# 6   JOB7    Software Engineer    Accenture        Noida   Full-time
#
#   Salary Range Experience Required Posted Date Application Deadline  \
# 1          5-8           2-5 years  25-12-2024           19-01-2025
# 2          20+          5-10 years  22-01-2025           29-01-2025
# 4        12-20           10+ years  26-12-2024           08-01-2025
# 5          5-8          5-10 years  27-12-2024           09-01-2025
# 6          5-8          5-10 years  30-12-2024           13-01-2025
#
#    Job Portal  Number of Applicants Education Requirement  \
# 1      Indeed                   462                   MBA
# 2  Naukri.com                   430                M.Tech
# 4      Indeed                   199                   MBA
# 5      Indeed                   281                  B.Sc
# 6    LinkedIn                   489                B.Tech
#
#                   Skills Required Remote/Onsite  Company Size
# 1                SQL, C++, Python        Remote  Large (500+)
# 2  Machine Learning, Excel, React        Remote  Large (500+)
# 4                UI/UX, C++, Java        Onsite  Small (1-50)
# 5                 SQL, React, C++        Remote  Large (500+)
# 6                SQL, Python, C++        Hybrid  Large (500+)

# %% [markdown]
# **GROUPING**

# %%
ijm.groupby('Job Type')['Number of Applicants'].mean() # Average number of applicants per Job Type
# Out:
# Job Type
# Contract      256.303546
# Full-time     259.900823
# Internship    255.400000
# Part-time     255.339268
# Name: Number of Applicants, dtype: float64

# %%
ijm.groupby('Salary Range')['Number of Applicants'].mean()
# Out:
# Salary Range
# 12-20    254.488441
# 20+      258.448085
# 3-5      258.899399
# 5-8      256.369297
# 8-12     255.462153
# Name: Number of Applicants, dtype: float64

# %%
# Number of jobs per Company
ijm.groupby('Company Name').size().rename('Job Listing')
# Out:
# Company Name
# Accenture    1954
# Amazon       2086
# Deloitte     1983
# Google       2004
# HCL          2023
# IBM          1944
# Infosys      1981
# Microsoft    1977
# TCS          1979
# Wipro        2069
# Name: Job Listing, dtype: int64

# %% [markdown]
# **SORTING**

# %%
ijm.sort_values(by='Posted Date').tail(9)
# Out:
#          Job ID               Job Title Company Name Job Location    Job Type  \
# 14572  JOB14573     Marketing Executive      Infosys    Ahmedabad   Full-time
# 2677    JOB2678  Cyber Security Analyst    Microsoft       Jaipur  Internship
# 9197    JOB9198  Cyber Security Analyst          IBM       Jaipur  Internship
# 12941  JOB12942  Cyber Security Analyst       Amazon    Hyderabad   Full-time
# 17971  JOB17972       Financial Analyst     Deloitte       Mumbai    Contract
# 2690    JOB2691         Product Manager       Amazon      Kolkata   Full-time
# 9173    JOB9174       Financial Analyst     Deloitte      Chennai   Part-time
# 9215    JOB9216    Sales Representative       Amazon    Ahmedabad   Part-time
# 7796    JOB7797  Cyber Security Analyst          IBM         Pune   Full-time
#
#       Salary Range Experience Required Posted Date Application Deadline  \
# 14572          20+          5-10 years  31-12-2024           17-01-2025
# 2677         12-20           2-5 years  31-12-2024           25-01-2025
# 9197           5-8           0-2 years  31-12-2024           12-01-2025
# 12941          20+           10+ years  31-12-2024           28-01-2025
# 17971        12-20          5-10 years  31-12-2024           10-01-2025
# 2690           20+           2-5 years  31-12-2024           07-01-2025
# 9173           20+           10+ years  31-12-2024           30-01-2025
# 9215          8-12           10+ years  31-12-2024           26-01-2025
# 7796         12-20           0-2 years  31-12-2024           29-01-2025
#
#        Job Portal  Number of Applicants Education Requirement  \
# 14572    LinkedIn                   341                B.Tech
# 2677       Indeed                   417                M.Tech
# 9197   Naukri.com                   255                   PhD
# 12941      Indeed                   473                   PhD
# 17971    LinkedIn                   333                   PhD
# 2690   Naukri.com                   477                M.Tech
# 9173       Indeed                   123                  B.Sc
# 9215     LinkedIn                   488                M.Tech
# 7796   Naukri.com                   200                M.Tech
#
#                                 Skills Required Remote/Onsite     Company Size
# 14572                       Java, Python, UI/UX        Hybrid     Small (1-50)
# 2677               Machine Learning, SQL, UI/UX        Hybrid  Medium (51-500)
# 9197                           AWS, Python, C++        Remote     Large (500+)
# 12941               AWS, C++, Digital Marketing        Onsite     Small (1-50)
# 17971             Digital Marketing, C++, UI/UX        Remote  Medium (51-500)
# 2690   C++, Digital Marketing, Machine Learning        Remote  Medium (51-500)
# 9173             Java, UI/UX, Digital Marketing        Remote  Medium (51-500)
# 9215             Excel, Digital Marketing, Java        Onsite     Large (500+)
# 7796            Python, Java, Digital Marketing        Hybrid     Large (500+)

# %%
ijm.sort_index(ascending=False).head()
# Out:
#          Job ID             Job Title Company Name Job Location    Job Type  \
# 19999  JOB20000      Business Analyst    Accenture       Mumbai   Part-time
# 19998  JOB19999  Sales Representative      Infosys      Kolkata  Internship
# 19997  JOB19998      Graphic Designer        Wipro       Jaipur   Part-time
# 19996  JOB19997      Business Analyst    Accenture    Bangalore  Internship
# 19995  JOB19996   Marketing Executive     Deloitte         Pune   Full-time
#
#       Salary Range Experience Required Posted Date Application Deadline  \
# 19999          5-8           0-2 years  30-12-2024           13-01-2025
# 19998        12-20           2-5 years  20-01-2025           09-02-2025
# 19997          5-8          5-10 years  26-12-2024           16-01-2025
# 19996          20+           0-2 years  08-01-2025           27-01-2025
# 19995          5-8           2-5 years  13-01-2025           05-02-2025
#
#        Job Portal  Number of Applicants Education Requirement  \
# 19999      Indeed                    88                  B.Sc
# 19998  Naukri.com                   178                M.Tech
# 19997  Naukri.com                   319                   PhD
# 19996    LinkedIn                   482                   MBA
# 19995      Indeed                   171                   PhD
#
#                                   Skills Required Remote/Onsite  \
# 19999                           Java, C++, Python        Remote
# 19998                           Excel, C++, React        Onsite
# 19997  Machine Learning, Excel, Digital Marketing        Onsite
# 19996  Digital Marketing, React, Machine Learning        Onsite
# 19995               Machine Learning, Python, AWS        Remote
#
#           Company Size
# 19999  Medium (51-500)
# 19998     Large (500+)
# 19997     Small (1-50)
# 19996  Medium (51-500)
# 19995     Small (1-50)

# %%
ijm.sort_values(by='Number of Applicants')
# Out:
#          Job ID               Job Title Company Name Job Location    Job Type  \
# 560      JOB561          Data Scientist       Amazon       Jaipur   Full-time
# 13611  JOB13612     Marketing Executive      Infosys        Noida   Part-time
# 13033  JOB13034         Product Manager       Google        Noida  Internship
# 11986  JOB11987       Financial Analyst    Accenture    Bangalore   Full-time
# 5904    JOB5905  Cyber Security Analyst        Wipro        Noida  Internship
# ...         ...                     ...          ...          ...         ...
# 2247    JOB2248        Graphic Designer     Deloitte    Bangalore   Part-time
# 14513  JOB14514       Software Engineer          IBM        Noida   Part-time
# 14373  JOB14374        Business Analyst      Infosys    Ahmedabad  Internship
# 7679    JOB7680       Financial Analyst        Wipro    Ahmedabad   Part-time
# 7617    JOB7618     Marketing Executive          IBM    Ahmedabad    Contract
#
#       Salary Range Experience Required Posted Date Application Deadline  \
# 560            5-8          5-10 years  08-01-2025           27-01-2025
# 13611          5-8           2-5 years  08-01-2025           16-01-2025
# 13033          20+          5-10 years  05-01-2025           04-02-2025
# 11986        12-20           2-5 years  03-01-2025           29-01-2025
# 5904           3-5           0-2 years  12-01-2025           30-01-2025
# ...            ...                 ...         ...                  ...
# 2247          8-12          5-10 years  10-01-2025           05-02-2025
# 14513          3-5          5-10 years  19-01-2025           02-02-2025
# 14373        12-20           10+ years  21-01-2025           01-02-2025
# 7679           5-8           10+ years  03-01-2025           12-01-2025
# 7617           5-8           10+ years  13-01-2025           05-02-2025
#
#        Job Portal  Number of Applicants Education Requirement  \
# 560    Naukri.com                    10                   MBA
# 13611    LinkedIn                    10                M.Tech
# 13033      Indeed                    10                   MBA
# 11986    LinkedIn                    10                   MBA
# 5904   Naukri.com                    10                M.Tech
# ...           ...                   ...                   ...
# 2247     LinkedIn                   500                M.Tech
# 14513  Naukri.com                   500                   MBA
# 14373  Naukri.com                   500                M.Tech
# 7679       Indeed                   500                   PhD
# 7617   Naukri.com                   500                M.Tech
#
#                                 Skills Required Remote/Onsite     Company Size
# 560                         Excel, Java, Python        Onsite  Medium (51-500)
# 13611             Java, Excel, Machine Learning        Remote     Large (500+)
# 13033           UI/UX, Machine Learning, Python        Remote     Small (1-50)
# 11986            React, Machine Learning, Excel        Onsite     Large (500+)
# 5904                 Machine Learning, C++, SQL        Remote  Medium (51-500)
# ...                                         ...           ...              ...
# 2247                            React, AWS, SQL        Onsite  Medium (51-500)
# 14513             Machine Learning, C++, Python        Onsite     Small (1-50)
# 14373                          Java, Excel, AWS        Hybrid     Small (1-50)
# 7679                       Excel, React, Python        Remote     Small (1-50)
# 7617   C++, Digital Marketing, Machine Learning        Onsite     Large (500+)
#
# [20000 rows x 15 columns]

# %% [markdown]
# **AGGREGATIONS**

# %%
ijm['Number of Applicants'].min()
# Out:
# 10

# %%
ijm['Number of Applicants'].max()
# Out:
# 500

# %%
ijm['Number of Applicants'].mean()
# Out:
# 256.7233

# %%
print(int(ijm['Number of Applicants'].mean()))
# Out:
# 256

# %%
ijm['Number of Applicants'].var()
# Out:
# 20091.88103116164

# %% [markdown]
# **DATA VISUALIZATION**

# %%
#Filter top 5 Job Titles
top_jobs = ijm['Job Title'].value_counts().nlargest(5).index
filtered_df = ijm[ijm['Job Title'].isin(top_jobs)].copy()

#Split 'Skills Required' into separate skills
filtered_df['Skills Required'] = filtered_df['Skills Required'].str.split(',')

#Explode the list so each skill gets its own row
filtered_df = filtered_df.explode('Skills Required')

#Remove leading/trailing spaces
filtered_df['Skills Required'] = filtered_df['Skills Required'].str.strip()

#Plot
plt.figure(figsize=(12,6),facecolor='beige')
sns.countplot(y='Skills Required', hue='Job Title', data=filtered_df, order=filtered_df['Skills Required'].value_counts().index[:10])
plt.title('Top 10 Skills Required for Top 5 Job Titles')
plt.xlabel('Count')
plt.ylabel('Skill')
plt.legend(title='Job Title')
plt.show()

# %%
plt.figure(figsize=(8,6),facecolor='beige')
sns.countplot(x='Remote/Onsite', data=ijm,color='purple')
plt.title('Remote vs Onsite Jobs')
plt.show()

# %%
# Count occurrences
counts = ijm['Remote/Onsite'].value_counts()

# Get categories and values
categories = counts.index
values = counts.values

# Assign colors using NumPy
colors = np.full(len(values), 'yellow', dtype=object)      # all yellow
colors[np.argmax(values)] = 'red'                          # max becomes red

if len(values) > 2:
    middle_pos = np.argsort(values)[-2]                    # second highest position
    colors[middle_pos] = 'orange'                          # middle becomes orange

# Plot
plt.figure(figsize=(8,6),facecolor='lightblue')
sns.barplot(x=categories, y=values, hue=categories, legend=False, palette=colors.tolist())
#OR
#plt.bar(categories, values, color=colors.tolist())
plt.title('Remote vs Onsite Jobs with Color-coded Counts')
plt.xlabel('Job Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6,6),facecolor='lightblue')
colors = sns.color_palette('Set3')
ijm['Job Type'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,explode=(0.05,0.05,0.05,0.05), startangle=140, colors={'purple','violet','red','green'},wedgeprops={'edgecolor': 'black', 'linewidth': 1})
plt.title('Type of Job Distribution')
plt.ylabel('')  # Removes extra ylabel
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor='lightgrey')
sns.countplot(y='Job Location', data=ijm, order=ijm['Job Location'].value_counts().index[:10], hue='Job Location', palette='viridis', legend=False)
plt.title('Top 10 Job Locations')
plt.xlabel('Number of Jobs')
plt.ylabel('Job Location')
plt.show()
#You're explicitly saying: "Color the bars based on Job Location" using hue

# %%
#Convert Date Column to datetime
ijm['Posted Date'] = pd.to_datetime(ijm['Posted Date'], dayfirst=True)
#Group by Date and Count Jobs
jobs_over_time = ijm.groupby('Posted Date').size()
#plot
plt.figure(figsize=(10,6),facecolor='lightpink')
plt.plot(jobs_over_time.index, jobs_over_time.values, marker='d', color='purple')
plt.title('Job Postings Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Job Postings')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6),facecolor='pink')
sns.countplot(y='Education Requirement', data=ijm, order=ijm['Education Requirement'].value_counts().index,hue='Education Requirement', palette='colorblind')
plt.title('Education Requirement Distribution')
plt.xlabel('Number of Job Listings')
plt.ylabel('Education Requirement')
plt.show()

# %%
top_companies = ijm['Company Name'].value_counts().nlargest(5).index
filtered_df = ijm[ijm['Company Name'].isin(top_companies)]

plt.figure(figsize=(12,6),facecolor='lightgrey')
sns.countplot(y='Company Name', hue='Salary Range', data=filtered_df, palette='coolwarm')
plt.title('Salary Range Distribution for Top 5 Companies')
plt.xlabel('Number of Job Listings')
plt.ylabel('Company Name')
plt.legend(title='Salary Range', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# *TO FIND OUT THE RELATION BETWEEN AVG SALARY OF THE EMPLOYEE HOLDING A JOB TITLE IN EACH COMPANY USING LINE PLOT*

# %%
#extracting avg salary

ijm['Salary Range'] = ijm['Salary Range'].str.replace(r'(\d+)\+', r'\1', regex=True)

ijm[['Min Salary', 'Max Salary']] = ijm['Salary Range'].str.replace('LPA', '').str.strip().str.split('-', expand=True)
ijm['Min Salary'] = ijm['Min Salary'].astype(float)
ijm['Max Salary'] = ijm['Max Salary'].astype(float)
ijm['Average Salary (LPA)'] = (ijm['Min Salary'] + ijm['Max Salary']) / 2

grouped = ijm.groupby(['Company Name', 'Job Title'])['Average Salary (LPA)'].mean().reset_index()

# %%
#filtering top 5 companies
top_5_companies = ijm['Company Name'].value_counts().nlargest(5).index
filtered_df = ijm[ijm['Company Name'].isin(top_5_companies)]
#groupby comapny, job title and avg salary
grouped = filtered_df.groupby(['Company Name', 'Job Title'])['Average Salary (LPA)'].mean().reset_index()

# %%
plt.figure(figsize=(12,6),facecolor='pink')
for company in grouped['Company Name'].unique():
    company_data = grouped[grouped['Company Name'] == company]
    plt.plot(company_data['Job Title'], company_data['Average Salary (LPA)'], marker='o', label=company)

plt.title('Average Salary (LPA) by Job Title for Top 5 Companies')
plt.xlabel('Job Title')
plt.ylabel('Average Salary (LPA)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Company')
plt.grid(True)
plt.show()
